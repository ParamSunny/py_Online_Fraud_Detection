# %% [markdown]
# **Importing some library**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Importing csv file**

# %%
df = pd.read_csv('/content/tableConvert.com_edkhru.csv')

# %% [markdown]
# **Print the csv file**

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %% [markdown]
# **How many columns we have!**

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %% [markdown]
# **Numbers of Rows & Columns**

# %%
df.shape
# Out:
# (110, 11)

# %% [markdown]
# **What type of Data we have in our Dataset!**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   step            110 non-null    int64
#  1   type            110 non-null    object
#  2   amount          110 non-null    float64
#  3   nameOrig        110 non-null    object
#  4   oldbalanceOrg   110 non-null    float64
#  5   newbalanceOrig  110 non-null    float64
#  6   nameDest        110 non-null    object
#  7   oldbalanceDest  110 non-null    float64
#  8   newbalanceDest  110 non-null    float64
#  9   isFraud         110 non-null    int64
#  10  isFlaggedFraud  110 non-null    int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 9.6+ KB

# %% [markdown]
# **Now check for null value**

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %% [markdown]
# **Attributes in Type column**

# %%
df['type'].unique()
# Out:
# array(['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT'], dtype=object)

# %% [markdown]
# **Count of each Attribute**

# %%
df['type'].value_counts()
# Out:
# PAYMENT     62
# TRANSFER    24
# CASH_OUT    14
# DEBIT       10
# Name: type, dtype: int64

# %%
type=df['type'].value_counts()
quantity=type.values
type.values
# Out:
# array([62, 24, 14, 10])

# %%
transaction=type.index
type.index
# Out:
# Index(['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT'], dtype='object')

# %% [markdown]
# **Now plot a pieChart**

# %%
px.pie(df,values=quantity,names=transaction,hole=0.4,title="Distribution Of Transaction Type:")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.dropna()

# %% [markdown]
# **Replace the name with numbers**

# %%
df.replace(to_replace=['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT'],value=[1,2,3,4],inplace=True)
df
# Out:
#      step  type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0       1     1   9839.64  C1231006815       170136.0       160296.36
# 1       1     1   1864.28  C1666544295        21249.0        19384.72
# 2       1     2    181.00  C1305486145          181.0            0.00
# 3       1     3    181.00   C840083671          181.0            0.00
# 4       1     1  11668.14  C2048537720        41554.0        29885.86
# ..    ...   ...       ...          ...            ...             ...
# 105     1     1   1876.44  C1509309988          182.0            0.00
# 106     1     3  28404.60  C2091072548            0.0            0.00
# 107     1     3  75405.10   C263053820            0.0            0.00
# 108     1     3  50101.88  C1740826931            0.0            0.00
# 109     1     3  14121.82    C69062746            0.0            0.00
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# ...

# %% [markdown]
# **Now check for isFraud is True or False**

# %%
df['isFraud']=df['isFraud'].map({0:'NoFraud',1:'Fraud'})
df
# Out:
#      step  type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0       1     1   9839.64  C1231006815       170136.0       160296.36
# 1       1     1   1864.28  C1666544295        21249.0        19384.72
# 2       1     2    181.00  C1305486145          181.0            0.00
# 3       1     3    181.00   C840083671          181.0            0.00
# 4       1     1  11668.14  C2048537720        41554.0        29885.86
# ..    ...   ...       ...          ...            ...             ...
# 105     1     1   1876.44  C1509309988          182.0            0.00
# 106     1     3  28404.60  C2091072548            0.0            0.00
# 107     1     3  75405.10   C263053820            0.0            0.00
# 108     1     3  50101.88  C1740826931            0.0            0.00
# 109     1     3  14121.82    C69062746            0.0            0.00
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# ...

# %%
x=df[['type','amount','oldbalanceOrg','newbalanceOrig']]
x
# Out:
#      type    amount  oldbalanceOrg  newbalanceOrig
# 0       1   9839.64       170136.0       160296.36
# 1       1   1864.28        21249.0        19384.72
# 2       2    181.00          181.0            0.00
# 3       3    181.00          181.0            0.00
# 4       1  11668.14        41554.0        29885.86
# ..    ...       ...            ...             ...
# 105     1   1876.44          182.0            0.00
# 106     3  28404.60            0.0            0.00
# 107     3  75405.10            0.0            0.00
# 108     3  50101.88            0.0            0.00
# 109     3  14121.82            0.0            0.00
#
# [110 rows x 4 columns]

# %%
y=df.iloc[:,-2]
y
# Out:
# 0      NoFraud
# 1      NoFraud
# 2        Fraud
# 3        Fraud
# 4      NoFraud
#         ...
# 105    NoFraud
# 106    NoFraud
# 107    NoFraud
# 108    NoFraud
# 109    NoFraud
# Name: isFraud, Length: 110, dtype: object

# %% [markdown]
# Now we going to train our model

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
model=DecisionTreeClassifier()

# %%
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
model.score(xtest,ytest)
# Out:
# 0.9545454545454546
